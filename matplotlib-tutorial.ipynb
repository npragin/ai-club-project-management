# %% [markdown]
# # Matplotlib Tutorial
# Author: Lauren Gliane
#
# Welcome to the tutorial! To get you comfortable with using Matplotlib we will cover:
# 1. Why learn?
# 2. Plotting Lines/Points
# 3. Bar Charts and Histograms
# 4. Scatter plots
# 5. Box Charts
# 6. Customization (markers, line, labels, grids)

# %% [markdown]
# ## 1. Why Learn Matplotlib?
# Learning Matplotlib allows you to turn boring data into eye-catching, story-driven visuals. Whether you’re exploring trends, explaining your project results, or impressing in a presentation, Matplotlib lets you bring your data to life with colorful, customizable charts. It’s a must-have skill for turning numbers into something people can actually see, understand, and it makes your work stand out in any class, research project, or career path.
#
# In context of __Machine Learning applications__, Matplotlib can be used to:
# 1. __Understand model behavior__: visualization can offer insights into crucial behavior patterns like cluster formations, learning process of a neural netowkr, or showing decision boundaries.
# 2. __Hyperparameter tuning__: Plots can help with visualizing the effect of changing hyperparameters on your model's performance, which is helpful during the optimization process.

# %% [markdown]
# ## 2. Plotting A Line
# The `plt.plot()` function takes in two parameters. The first takes in the points on the x axis. The second takes in the points on the y axis. The function adds elements to the figures, but does not create a visible graph yet. `plt.show()` opens a graphical user interface (GUI) window to display your figures.
#
# _Note:_
#  _In Jupyter Notebooks, calling `plt.show()` in this tutorial is not necessary, but crucial when compiling in your own IDE._
#
# [Matplotlib Line Documentation](https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html)
#
# [matplotlib.plot() Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)
#
# [matplotlib.show() Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html)
#
# ### The Importance of Lines in ML
# [__Exploratory Data Analysis (EDA)__](https://www.geeksforgeeks.org/data-analysis/what-is-exploratory-data-analysis/) is a process involving steps to discover patterns, identify anomalies, and test model versions. In order to perform EDA, we need to visualize the data, using tools like Matplotlib. Other Python tools like Pandas can clean, filter, and manipulate your data. For now, Matplotlib is sufficient.

# %% [markdown]
# #### Importing libraries
# If any cell fails to run try running `pip install matplotlib`.
#
# For this exercise you won't need to import any libraries, but the code below demonstrates how to:

# %%
# import our libraries
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Demo: Test it out
# Run this code below to practice calling the `array()`, `plot()`, and `show()` functions from the matplotlib libraries.
#
# 1. Create an **array of x-points** (ranging 0 to 10) into **xpoints variable**
# 2. Create an **array of y-points** (ranging 0 to 240) into **ypoints variable**
# 3. Generate and show plot using **plot(xpoints, ypoints)** and **show()**

# %%
# create an array using the array() function in the numpy library
xpoints = np.array([0, 10])
ypoints = np.array([0, 240])

# generate and show our plot using the plot() and show() functions from pyplot library
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### Plotting Points
# To plot only specified points, use the shortcut 'o' as a third parameter to plot the points in the graph.
#
# The points or __markers__ can be changed to different symbols. The [matplotlib.markers Documentation](https://matplotlib.org/stable/api/markers_api.html) provides a key for all available customization symbols.
#
# ##### Exercise 1: Try out different shapes
# Use the shortcut `'s'` as the third parameter in `plt.plot(xpoints, ypoints, ' ')`to change the `'o'` marker to a square shape.

# %%
# create an array
xpoints = np.array([0, 10])
ypoints = np.array([0, 240])

# use the 'o' shortcut to only plot points, no line
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# #### Additonal Practice: Plotting Specific Points
# Below is an example of how to plot just the four coordinates (1,3), (2,7), (3,9), (5,2).
#
# #### Exercise 2: Try it out!
# On your own, alter the example code below and plot 3 coordinates (0,4), (3,7), and (9,17).

# %%
# two arrays of coords (1,3), (2,7), (3,9), (5,2)
xpoints = np.array([1, 2, 3, 5])
ypoints = np.array([4, 7, 9, 2])

plt.plot(xpoints, ypoints)
# plt.show()

# %% [markdown]
# ## 3. Bar Charts and Histograms

# %% [markdown]
# ### Bar Charts
#
# Bar charts are important in machine learning for:
# 1. __Visualizing and comparing categorical data:__ bar charts allow for easy identification of higher or lower values between categories.
# 2. __Identifying patterns:__ trends in data are highlighted by bar charts and can show relationships within your data.
# 3. __Evaluating model performance:__ performance metrics (such as error rates or accuracy) are often visualized through bar charts to compare the effect of changes.
#
#
# Matplotlib uses the `plt.bar()` function to create bar charts.
#
# [matplotlib.pyplot.bar Documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html)
#
#
#
# #### Demo: Try it out!
# Our x points will be fruit names (categories). Our y points will be the amount of fruits (values).

# %%
# categories and values
x = np.array(["Apples", "Bananas", "Cherries", "Dates"])
y = np.array([5, 7, 3, 8])

plt.bar(x, y)
plt.show()

# %% [markdown]
# #### Exercise 3: Challenge yourself!
# Use the code above to create a **horizontal bar** chart and change the fruits and values to roughly show the **top 4** fruits according to this [report of popular fruits](https://www.freshproduce.com/resources/consumer-trends/top-20/).
#
# _Hint: Use [plt.barh()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html) instead of just `plt.bar()`to create horizontal chart_

# %%
# write your code here

# %% [markdown]
# ## Histograms
# Histograms are used to show the distribution of a dataset, this is helpful when identifying distribution type as normal, skewed, or another pattern. The distribution visualization feature of histograms can also provide valuable insights that can guide:
# 1. [Data Preprocessing](https://www.geeksforgeeks.org/machine-learning/data-preprocessing-machine-learning-python): matplotlib allows for visualization and scaling to inspect data structure
# 2. [Feature Engineering](https://www.geeksforgeeks.org/machine-learning/what-is-feature-engineering/): turning raw data in to relevant information to improve your model
# 3. [Model Selection](https://www.geeksforgeeks.org/machine-learning/model-selection-for-machine-learning/): choosing a model fit for the given problem helps avoid overfitting and underfitting
#
# #### Demo: Try it out!
# To generate our histogram use the the `hist()` function to do so.
# We'll use the [numpy.random.normal()](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate 250 random values with mean 170 and std 10.

# %%
# generate 250 random values with mean 170 and std 10
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# #### Exercise 4: Challenge yourself!
# Alter the code above to **change the number of bins** in the histogram using the bins parameter (e.g., `plt.hist(x, bins=20)`). Try experimenting with different bin counts and observe how it changes the distribution shape.

# %%
# write your code here

# %% [markdown]
# ## 4. Scatter Plots
#
# Scatter plots are important in ML for visually identifying patterns, trends, and correlations between variables, detecting outliers, and understanding the distribution of data.
# 1. Pattern and Trend Recognition: identifying themes within a dataset (image/voice recognition, movement/behavior patterns)
# 2. Understanding Data Distribution: discovering positive, negative, or no correlation between variable changes
# 3. Predictive Modeling Insights: provides insights to comparing actual values against predicted values
#
# #### Demo: Try it out!
# Use the [scatter()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) function to generate a scatter plot from the x and y array.

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11])
y = np.array([99, 86, 87, 88, 100, 86, 103, 87, 94, 78])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# #### Exercise 5: Challenge yourself!
# Modify the scatter plot to show red dots instead of default blue ones. Hint: add a `color='red'` parameter in `scatter()`.

# %%
# write your code here

# %% [markdown]
# ## 5. Box Charts
# A box plot (or whisker plot) shows the distribution, median, and outliers of a dataset.
# Plotting box charts, or box-and-whisker plots, is important for machine learning (ML) applications because they are a compact and highly effective method for visualizing data distribution and detecting outliers. This is a crucial step in the [exploratory data analysis (EDA)](https://www.geeksforgeeks.org/data-analysis/what-is-exploratory-data-analysis/) and [data preprocessing](https://www.geeksforgeeks.org/machine-learning/data-preprocessing-machine-learning-python) phases of any ML project.
#
# Use the [boxplot()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html) function to create one!
#
#
#
# #### Demo: Try it out!
# We'll use [numpy.random.normal()](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate random numbers again.

# %%
# generate random data
data = np.random.normal(100, 20, 200)

plt.boxplot(data)
plt.show()

# %% [markdown]
# #### Exercise 6: Challenge yourself!
# Generate two sets of random data and plot them together in the same box chart by passing a list of datasets into boxplot().
# For example:
#
# `plt.boxplot([data1, data2])`
# Hint: Create data1 and data2 variables and don't forget the [brackets].

# %%
# use this space for the box plot challenge

# %% [markdown]
# ## 6. Customization
# The default graphs look clean, but customizing our graphs can better represent data themes and showcase your data. We'll cover how to add/change:
# - [markers](https://matplotlib.org/stable/api/markers_api.html)
# - [linestyles](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)
# - [axis labels](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html)
# - [grid](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.grid.html)
#
# #### Try it out!
# Test the code below to see all four customizers in action.

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 6, 8, 14, 20])

# marker: circle
# linestyle:  dashed
# color: purple
plt.plot(x, y, marker='o', linestyle='--', color='purple')

plt.show()

# %% [markdown]
# ### Lines and Markers
#
# A variety of [linestyles](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html) and [markers](https://matplotlib.org/stable/api/markers_api.html) are provided in the matplotlib library. Complete the challenge below to the specified colors and markers, but also test out other symbols on your own!
#
# #### Exercise 7: Challenge yourself!
# Try customizing the line style to be dotted (':'), use triangle markers ('^'), and set the line color to green. _(Hint: Check through the linked documentation above)_

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 6, 8, 14, 20])


#___Challege____
# marker: dotted
# linestyle:  triangles
# line color: green
#_______________

# write your code below
plt.plot(x, y, marker='^', linestyle=':', color='green')

# %% [markdown]
# ### Labeling: Title and Axes
# One of the most important parts: Let's name our [title](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html), [x axis](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html), and [y axis](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html).
# (Click for matplotlib Documentation)
#
# #### Exercise 8: Challenge yourself!
# Use the following functions to create labels for the Exercise 7 graph:
# 1. `matplotlib.pyplot.title(your_title)`
# 2. `matplotlib.pyplot.xlabel(your_xlabel)`
# 3. `matplotlib.pyplot.ylabel(your_ylabel)`
#
# _(remember we use shortened `plt` for `matplotlib.pyplot`)_

# %%
# ** same code from exercise 7 **

x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 6, 8, 14, 20])

plt.plot(x, y, marker='o', linestyle='--', color='purple')

# write your code here


#___________________

plt.show()

# %% [markdown]
# ### Grid

# %%
# write your code here

# %% [markdown]
# ## Key
#
# #### Exercise 1: Square Points
# ![exercise1_key.png](attachment:image.png)
#
# #### Exercise 2: Custom Coordinates
# ![exercise2_key.png](attachment:image-2.png)
#
# #### Exercise 3: Bar Chart of Popular Fruits
# I use the percentages as values for the graph!
# ![image-3.png](attachment:image-3.png)
#
# #### Exercise 4: Histogram Bins sizes
# I used 20 as my bin value. What happens when the bin count is low?
# ![image-4.png](attachment:image-4.png)
#
# #### Exercise 5: Scatter plot dots
# ![image-5.png](attachment:image-5.png)
# #### Exercise 6: Box plot
# This is how I created variable `data2`.
# `data2 = np.random.normal(140, 10, 200)`
# ![image-6.png](attachment:image-6.png)
# #### Exercise 7: Customization Challenge
# ![image-8.png](attachment:image-8.png)
# #### Exercise 8: Labeling Basics
# ![image-7.png](attachment:image-7.png)
